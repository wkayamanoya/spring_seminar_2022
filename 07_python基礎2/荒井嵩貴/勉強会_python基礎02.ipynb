# %% [markdown]
# 課題1

# %%
import numpy as np

a = ['m', 'c', 'i', 'e', 'p', 'r', 'e', 't', 'o', ' ', 'o', 'o', 'i', 's', 'g', 'o', 'p']
b = ['a', 'h', 'n', ' ', 'e', 'c', 'p', 'i', 'n', 'r', 'b', 't', 'c', '-', 'r', 'u', '!']

text=[a + b for a,b in zip(a,b)]

for ch in text:
  print(ch, end="")
# Out:
# machine perception robotics-group!

# %% [markdown]
# 課題2

# %%
import numpy as np

pred = np.array([1, 3, 1, 2, 5, 3, 0])
targets = np.array([0, 3, 2, 1, 5, 0, 0])

acc = np.sum(pred==targets)/len(pred)
print(acc)
# Out:
# 0.42857142857142855

# %% [markdown]
# 課題3

# %%
import numpy as np

X = np.random.rand(20, 15)
Z = (X-np.mean(X))/np.std(X)
print(Z)
# Out:
# [[-1.03586538  1.115334    1.24354469  0.67372986 -0.44195149 -0.52490894
#   -0.31227269  0.76052519  0.33525372  1.07696012  0.83732437 -1.36615912
#    0.71199636 -0.70538724 -0.8646648 ]
#  [ 1.65233786  0.75689556 -1.528038    0.8534613  -1.5650018   0.73657863
#   -1.63367142 -1.49931207 -1.37432061  0.85680631 -0.64573321 -0.21423369
#    0.53624665 -1.67293948  1.54399203]
#  [ 1.46596643  0.31968174  1.5091543  -1.13905123  0.23735968 -0.24154776
#    1.75213242 -0.67190723 -0.41804281  0.55740558  0.8493404  -0.62466046
#    0.92382     0.2077282  -1.69142187]
#  [-0.90573941  0.78109496  0.63255897 -1.27525412  0.3544708   0.79467
#   -1.39504639  1.27451941  0.70159299 -1.77094718 -1.57937841  1.39746538
#    0.33852928 -1.21322172 -0.77140717]
#  [ 0.315272   -0.0736325  -1.56330521 -0.09122973 -0.17418431  1.66344908
#   -0.85293684  0.42586409 -0.12574519  1.28655896 -1.80434512 -0.62743904
#   -0.92527203 -0.54402583 -1.57192815]
#  [-0.59613419 -0.4833228   0.58441737 -1.53582439  0.46313379  0.06386102
#   -0.21675184  1.61781904 -1.19920114 -0.8650572  -1.69776433 -0.63903868
#   -0.39055493 -0.60739724  0.3620664 ]
#  [ 0.71789787 -0.61709484  0.39760039 -1.50279634  1.77162675 -0.25576814
#   -0.49532144  0.19350852  1.02525146 -0.74106231  0.8882902  -0.15063558
#    1.00068813  0.07147016  0.19852676]
#  [ 0.59019651  0.31732936  1.05042339 -1.37169737  1.27705183 -0.15373206
#    0.21092865  1.16557609 -1.05671633  0.28541099  0.62184848  0.44993145
#   -0.16726864 -0.23749131  0.69622151]
