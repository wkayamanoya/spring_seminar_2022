# %% [markdown]
# **学籍番号：ER19069\
# 氏名　　：福井雅弥**

# %% [markdown]
# **課題１**　machine perception robotics-group! の出力が出るようにしよう．

# %%
import numpy as np

a = ['m', 'c', 'i', 'e', 'p', 'r', 'e', 't', 'o', ' ', 'o', 'o', 'i', 's', 'g', 'o', 'p']
b = ['a', 'h', 'n', ' ', 'e', 'c', 'p', 'i', 'n', 'r', 'b', 't', 'c', '-', 'r', 'u', '!']

for n,m in zip(a,b):
  print(n+m,end="")
# Out:
# machine perception robotics-group!

# %% [markdown]
# **課題2**　0.42857142857142855の出力がでるようにしよう．

# %%
import numpy as np
pred = np.array([1, 3, 1, 2, 5, 3, 0])
targets = np.array([0, 3, 2, 1, 5, 0, 0])

bool = pred == targets
#print("correct answers = ",bool.sum())
print("accuracy rate = ",bool.sum()/len(pred)) #正解数/総数
# Out:
# accuracy rate =  0.42857142857142855

# %% [markdown]
# **課題3**　行列 𝑋 を標準化した 𝑍 を出力しよう．

# %%
import numpy as np
X = np.random.rand(20, 15)

#print(X)
Z = (X - np.mean(X)) / np.std(X)  #(要素値-平均値)/標準偏差
print("Xを標準化したZ = \n",Z)
# Out:
# 標準化したZ =
#  [[-1.44505965  0.73527509  0.77706775  1.04919491 -0.65287485  0.79015025
#   -1.07961164 -0.61023455  0.61315724 -1.25543356  0.41694443 -0.35630494
#    0.23569396  1.55941274 -0.388058  ]
#  [ 0.09634103 -0.00270332  0.5340212   0.18990111 -0.69314026 -0.89721864
#   -0.00296944  0.52042665 -0.49967101 -1.56403837 -0.87234822  0.29774416
#    0.88236477  1.43819486 -0.67134213]
#  [-0.71897921 -1.39503263 -1.39325947  1.30068584 -1.20396477  0.53937876
#    0.83051144 -0.25244527  0.23124222  0.86261469  0.40207374  0.62651526
#   -1.04890195 -1.46382059 -0.33691291]
#  [ 0.25680087  1.1648517   1.31652706  0.49669202  0.37715312 -0.64594458
#    1.60472897  0.49902632 -0.04107255 -0.75473198  1.29398503  0.01047733
#    0.89567459 -0.06874337  0.93305257]
#  [-1.09566534  0.17313024 -0.63795955  0.42125392  0.6475935   0.7354864
#   -1.41769004  1.53022163 -1.2373652  -1.42222728 -1.43342882  0.19543369
#   -0.33344746  1.18200044 -1.56940689]
# ...
